# %%
import pandas as pd

data = pd.read_csv("data_flights.csv", sep = ",")
data.shape
# Out:
# /var/folders/1t/90w39hxx4r37g9xks62hmczr0000gn/T/ipykernel_13192/46907731.py:3: DtypeWarning: Columns (19,20,21,22,26,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data_flights.csv", sep = ",")
# (87262, 34)

# %%
data.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'icao_code', 'iata_code',
#        'gps_code', 'local_code', 'home_link', 'wikipedia_link', 'keywords',
#        'icao24', 'callsign', 'country_icao', 'time_at_position', 'longitude',
#        'latitude', 'altitude', 'on_ground', 'speed_kmh', 'true_track',
#        'vertical_rate', 'sensors', 'geo_altitude', 'spi', 'located_at'],
#       dtype='object')

# %%
data.head(100)
# Out:
#           id ident           type  \
# 0     6523.0   00A       heliport
# 1   323361.0  00AA  small_airport
# 2     6524.0  00AK  small_airport
# 3     6525.0  00AL  small_airport
# 4   506791.0  00AN  small_airport
# ..       ...   ...            ...
# 95  506122.0  01NR       heliport
# 96    6615.0  01NV  small_airport
# 97    6616.0  01NY       heliport
# 98  347920.0  01OH       heliport
# 99    6617.0  01OI       heliport
#
#                                             name  latitude_deg  longitude_deg  \
# 0                              Total RF Heliport     40.070985     -74.933689
# 1                           Aero B Ranch Airport     38.704022    -101.473911
# 2                                   Lowell Field     59.947733    -151.692524
# 3                                   Epps Airpark     34.864799     -86.770302
# 4                           Katmai Lodge Airport     59.093287    -156.456699
# ..                                           ...           ...            ...
# ...
